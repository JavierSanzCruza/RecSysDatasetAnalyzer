# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Degree distributions

# %%
file = "E:\\datasets\\yahooR6B\\data\\analysis-python\\0\\pop-user-item.txt"
f = open(file)
x = []
y = []

header = True
for line in f:
    if header:
        header = False
    else:
        line.replace('\n','')
        data = line.split("\t")
        x.append(int(data[0]))
        y.append(int(data[1]))

# %%
plt.plot(x,y,'o', color='blue', markersize=4)
plt.xlabel('Series', fontsize=18, family='Linux Libertine')
plt.xscale('log')
plt.xticks(fontsize=16, family='Linux Libertine')
plt.ylabel('Num. ratings', fontsize=18, family='Linux Libertine')
plt.yscale('log')
plt.yticks(fontsize=16, family='Linux Libertine')
plt.title('Item distribution', fontsize=22, family='Linux Libertine')

plt.savefig("E:\\datasets\\yahooR6B\\data\\analysis-python\\0\\pop-user-items-impr.pdf")

# %% [markdown]
# # Time series

# %%
file = "E:\\datasets\\yahooR6B\\data\\analysis-python\\50\\time-items.txt"
f = open(file)
times_series = []
series_series = []

header = True
for line in f:
    if header:
        header = False
    else:
        line.replace('\n','')
        data = line.split("\t")
        times_series.append(int(data[0]))
        series_series.append(int(data[1]))

# %%
file = "E:\\datasets\\yahooR6B\\data\\analysis-python\\50\\time-users.txt"
f = open(file)
times_users = []
series_users = []

header = True
for line in f:
    if header:
        header = False
    else:
        line.replace('\n','')
        data = line.split("\t")
        times_users.append(int(data[0]))
        series_users.append(int(data[1]))

# %%
fig, (axseries,axuser) = plt.subplots(2,1, figsize = (10,30))

plt.setp(axseries.get_xticklabels(),fontsize=20, family='Linux Libertine' )
plt.setp(axuser.get_xticklabels(),fontsize=20, family='Linux Libertine' )
plt.setp(axseries.get_yticklabels(),fontsize=20, family='Linux Libertine' )
plt.setp(axuser.get_yticklabels(),fontsize=20, family='Linux Libertine' )

axseries.plot(series_series,times_series,'o', color='black', markersize=1)
axseries.set_xlabel('Timestamp', fontsize=24, family='Linux Libertine')
axseries.set_ylabel('Series', fontsize=24, family='Linux Libertine')
axseries.set_title('Time distribution (series)', fontsize=32, family='Linux Libertine')

axuser.plot(series_users,times_users, 'o', color='black', markersize=1)
axuser.set_xlabel('Timestamp', fontsize=24, family='Linux Libertine')
axuser.set_ylabel('Users', fontsize=24, family='Linux Libertine')
axuser.set_title('Time distribution (users)', fontsize=32, family='Linux Libertine')

plt.savefig("E:\\datasets\\yahooR6B\\data\\analysis-python\\50\\time-items.png", dpi=300)

# %% [markdown]
# ## Impressions

# %%
file = "E:\\datasets\\yahooR6B\\data\\analysis-python\\50\\impr-items.txt"
f = open(file)
x = []
y = []

header = True
for line in f:
    if header:
        header = False
    else:
        line.replace('\n','')
        data = line.split("\t")
        x.append(int(data[0]))
        y.append(int(data[1]))

# %%
plt.plot(x,y,'o', color='blue', markersize=4)
plt.xlabel('Items', fontsize=22, family='Linux Libertine')
plt.xscale('log')
plt.xticks(fontsize=20, family='Linux Libertine')
plt.ylabel('Num. impressions', fontsize=22, family='Linux Libertine')
plt.yscale('log')
plt.yticks(fontsize=20, family='Linux Libertine')
plt.title('Impression distribution (series)', fontsize=24, family='Linux Libertine')

plt.savefig("E:\\datasets\\yahooR6B\\data\\analysis-python\\50\\impr-distrib-items.pdf")

# %%
file = "E:\\datasets\\yahooR6B\\data\\analysis-python\\50\\impr-user.txt"
f = open(file)
x = []
y = []

header = True
for line in f:
    if header:
        header = False
    else:
        line.replace('\n','')
        data = line.split("\t")
        x.append(int(data[0]))
        y.append(int(data[1]))

# %%
plt.plot(x,y,'o', color='blue', markersize=4)
plt.xlabel('Series', fontsize=22, family='Linux Libertine')
plt.xscale('log')
plt.xticks(fontsize=20, family='Linux Libertine')
plt.ylabel('Num. impressions', fontsize=22, family='Linux Libertine')
plt.yscale('log')
plt.yticks(fontsize=20, family='Linux Libertine')
plt.title('Impression distribution (users)', fontsize=24, family='Linux Libertine')

plt.savefig("E:\\datasets\\yahooR6B\\data\\analysis-python\\50\\impr-distrib-users.pdf")
